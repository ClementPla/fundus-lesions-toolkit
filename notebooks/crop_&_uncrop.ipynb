# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cv2
sys.path.append('../lib/fundus_lesions_toolkit')
from utils.images import open_image, plot_image, autocrop_fundus, pad_given_margins, autofit_fundus_resolution, reverse_autofit

# %%
example_path = '../imgs/rfmid_sample_1.png'
img = open_image(example_path)
plot_image(img, title=f'Sample from RFMID {img.shape}')
cropped_img, roi, margins = autocrop_fundus(img)
plot_image(cropped_img, title=f'Cropped Image {cropped_img.shape}')

padded_img = pad_given_margins(cropped_img, margins)
plot_image(padded_img, title=f'Reverse cropping {padded_img.shape}')

autofit_fundus, params = autofit_fundus_resolution(img, 512)
plot_image(autofit_fundus, title=f'Autofit {autofit_fundus.shape}')

back_to_original_fundus = reverse_autofit(autofit_fundus, **params)
plot_image(back_to_original_fundus, title=f'Back to original {back_to_original_fundus.shape}')

# %%
tensor = np.concatenate([img, img], 2)

# %%
autofit_fundus, params = autofit_fundus_resolution(tensor, 512)

# %%
autofit_fundus.shape
# Out:
# (512, 512, 6)
